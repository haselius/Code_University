# %%
import sympy as sp
from numpy.linalg import inv
import numpy as np
import matplotlib.pyplot as plt

# %%
#Явный Эйлер
Y = [1, 1.08905, 1.15295, 1.18811, 1.193, 1.1682, 1.11628, 1.04146, 0.949126, 0.84523, 0.735759]
YEi = [1, 1.1, 1.18, 1.23436, 1.25888, 1.25133, 1.21176, 1.14255, 1.04828, 0.935152, 0.810425]
A = [1, 1.09095, 1.15751, 1.19572, 1.20094, 1.17639, 1.12447, 1.04932, 0.956324, 0.851455, 0.740783]
MEi = [1, 1.1, 1.17718, 1.22682, 1.24606, 1.23419, 1.1926, 1.12457, 1.03491, 0.929396, 0.814226]
RK = [1, 1.09095, 1.15751, 1.19572, 1.20361, 1.18131, 1.13104, 1.0568, 0.963908, 0.858419, 0.746542]
plt.figure(figsize = (10,10))
plt.plot(Y, color = 'black',label = 'фукнция')
plt.plot(YEi,label = 'Явный метод Эйлера')
plt.plot(MEi,label = 'Неявный метод Эйлера')
plt.plot(RK,label = 'Метод Рунге-Кутты')
plt.plot(A,label = 'Метод Aдамса')
plt.legend()

# %%
#Модифицированный Эйлер
Y = [1, 1.08905, 1.15295, 1.18811, 1.193, 1.1682, 1.11628, 1.04146, 0.949126, 0.84523, 0.735759]
MEi = [1, 1.1, 1.17718, 1.22682, 1.24606, 1.23419, 1.1926, 1.12457, 1.03491, 0.929396, 0.814226]
plt.figure(figsize = (10,10))
plt.plot(Y, color = 'black',label = 'фукнция')
plt.plot(MEi, color = 'red',label = 'Модифицированый метод Эйлера')
plt.legend()

# %%
#Метод Рунге-Кутты
Y = [1, 1.08905, 1.15295, 1.18811, 1.193, 1.1682, 1.11628, 1.04146, 0.949126, 0.84523, 0.735759]
RK = [1, 1.09095, 1.15751, 1.19572, 1.20361, 1.18131, 1.13104, 1.0568, 0.963908, 0.858419, 0.746542]
plt.figure(figsize = (10,10))
plt.plot(Y, color = 'black',label = 'фукнция')
plt.plot(RK, color = 'red',label = 'Метод Рунге-Кутты')
plt.legend()

# %%
#Метод Aдамса
Y = [1, 1.08905, 1.15295, 1.18811, 1.193, 1.1682, 1.11628, 1.04146, 0.949126, 0.84523, 0.735759]
A = [1, 1.09095, 1.15751, 1.19572, 1.20094, 1.17639, 1.12447, 1.04932, 0.956324, 0.851455, 0.740783]
plt.figure(figsize = (10,10))
plt.plot(Y, color = 'black',label = 'фукнция')
plt.plot(A, color = 'red',label = 'Метод Aдамса')
plt.legend()

# %%
#Метод пристрелки
Y2 = [0, -0.131652, -0.267949, -0.414214, -0.57735]
P = [0, -0.132956, -0.269803, -0.415739, -0.57735]
K = [0, -0.134678, -0.269963, -0.415921, -0.57735]
plt.figure(figsize = (10,10))
plt.plot(Y2, color = 'black',label = 'фукнция')
plt.plot(P,label = 'Метод пристрелки')
plt.plot(K,label = 'Конечно-разностный метод')
plt.legend()
